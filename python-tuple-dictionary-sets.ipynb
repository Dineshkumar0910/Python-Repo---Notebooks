# %%
my_tup1 = (65,5,'Idly')
my_tup1
# Out:
# (65, 5, 'Idly')

# %%
type(my_tup1)
# Out:
# tuple

# %%
my_tup2 = (5)
type(my_tup2)
# Out:
# int

# %%
my_tup3 = ('tuple')
type(my_tup3)
# Out:
# str

# %%
my_tup4 = ('Tuple',)
type(my_tup4)
# Out:
# tuple

# %%
len(my_tup1)
# Out:
# 3

# %%
my_tup1[0]
# Out:
# 65

# %%
#Dictionary
my_dict1 = {'key1': 'Virat','key2':'Smith','key3':'Babar'}
my_dict1
# Out:
# {'key1': 'Virat', 'key2': 'Smith', 'key3': 'Babar'}

# %%
type(my_dict1)
# Out:
# dict

# %%
my_dict1['key2']
# Out:
# 'Smith'

# %%
my_dict2 = {'1': 'Virat','2':'Smith','3':'Babar','4':[1,2,3,4]}

# %%
my_dict2['4']
# Out:
# [1, 2, 3, 4]

# %%
my_dict2['4'][1]
# Out:
# 2

# %%
my_dict2.keys()
# Out:
# dict_keys(['1', '2', '3', '4'])

# %%
my_dict2.values()
# Out:
# dict_values(['Virat', 'Smith', 'Babar', [1, 2, 3, 4]])

# %%
my_dict2.items()
# Out:
# dict_items([('1', 'Virat'), ('2', 'Smith'), ('3', 'Babar'), ('4', [1, 2, 3, 4])])

# %%
#Set
my_set1 = {'Raina','Shewag',2,67,8,3}
my_set1
type(my_set1)
# Out:
# set

# %%
my_set2 = {}
type(my_set2)
# Out:
# dict

# %%
my_set3 = set(('Rajni','Kamal','Arjun'))
my_set3
# Out:
# {'Arjun', 'Kamal', 'Rajni'}

# %%
my_set1[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_27/1727227067.py in <module>
# ----> 1 my_set1[1]
#
# TypeError: 'set' object is not subscriptable

# %%
my_set3[1] = 'Vikram'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_27/2994699169.py in <module>
# ----> 1 my_set3[1] = 'Vikram'
#
# TypeError: 'set' object does not support item assignment

# %%
my_set1.add('Warner')
my_set1
# Out:
# {2, 3, 67, 8, 'Raina', 'Shewag', 'Warner'}

# %%
my_set1.update(['Kane','Jadeja','Bummbrah'])
my_set1
# Out:
# {2, 3, 67, 8, 'Bummbrah', 'Jadeja', 'Kane', 'Raina', 'Shewag', 'Warner'}

# %%
my_set1.pop()
my_set1
# Out:
# {2, 3, 67, 8, 'Jadeja', 'Kane', 'Raina', 'Shewag', 'Warner'}

# %%
my_set1.remove('Kane')
my_set1
# Out:
# {2, 3, 67, 8, 'Jadeja', 'Raina', 'Shewag', 'Warner'}

# %%
my_set1.discard('Dhoni')
my_set1
# Out:
# {2, 3, 67, 8, 'Jadeja', 'Raina', 'Shewag', 'Warner'}

# %%
my_set1.remove('Dhoni')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_27/1126014904.py in <module>
# ----> 1 my_set1.remove('Dhoni')
#
# KeyError: 'Dhoni'

# %%
my_set1.clear()

# %%
my_set1.clear()
# Out:
# set()

# %%
del my_set1
my_set1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27/3163718549.py in <module>
#       1 del my_set1
# ----> 2 my_set1
#
# NameError: name 'my_set1' is not defined
