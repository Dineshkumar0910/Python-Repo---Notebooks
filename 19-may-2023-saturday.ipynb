# %%
a = 10
"""
ergerg  \n \t 
ergregre
evrev
"""
a = input()
print("Welcome",a) #this is print
#sigle line

# %%
#Lists - Mutable
a = [43,65,2134]
b = [32,65.3,'apple']
print(a)
print(b)

# %%
snacks = list(('cookies','juices','fruits','munchies','choclates',"gems","nuts"))
print(snacks)
print(type(snacks))

# %%
print(len(snacks))

# %%
#Accessing the list - indexing,slicing
#indexing - 0,1,2,
print(snacks[0])
print(snacks[-1)
print(snacks[0:3])
print(snacks[-1:-2])

# %%
cricket = ['india','pakistan','aust','srilanka',['csk','rcb','kkr']]

# %%
print(cricket[4][1])

# %%
print(cricket[::-1])

# %%
print(cricket[2:])

# %%
print(cricket[:3])

# %%
#list fns - append(), inset(), extend()

# %%
cricket.append('USA')
print(cricket)

# %%
cricket.append(['England','Wales','Newzealand'])
print(cricket)

# %%
cricket.insert(2,'Bangladesh')
print(cricket)

# %%
cricket.insert(5,[1,2,3,4])
print(cricket)

# %%
cricket.extend(['swiz','snow','watch'])
print(cricket)

# %%
cricket[3] = 'australia'
print(cricket)

# %%
cricket[9:13] = ['Zimbabwe','Africa','Japan']
print(cricket)

# %%
#remove(), pop(), clear(), del

# %%
cricket.remove(['csk','rcb','kkr'])
print(cricket)

# %%
cricket.pop(2)
print(cricket)

# %%
cricket.pop()
print(cricket)

# %%
cricket.clear()
print(cricket)

# %%
del cricket

# %%
print(cricket)

# %%
#Tuple
players = ('Virat',18,76.5)
print(type(players))

# %%
score  = ()
print(type(score))

# %%
loca = tuple(('chennai','bangalore','kochin'))
print(loca)

# %%
actor = ('srk','salman','vikram','rajni',['prabahs','Ajit','Vijay'])
print(actor)

# %%
direc = ('Shankar',)
print(type(direc))

# %%
print(actor[-1])
print(actor[3])
print(actor[2:5])
print(actor[-1][1])

# %%
print(len(actor))

# %%
ac = list(actor)
ac.append('Maheshbabu')
actor = tuple(ac)
print(actor)

# %%
#Set
fruits = {'apple','kiwi','fig','jack','lemon','fig','lemon'}
print(type(fruits))
print(fruits)

# %%
len(fruits)

# %%
num = {}
print(type(num))

# %%
print(fruits[1])

# %%
sub = set(('Maths','Graphics','Physics','Language'))
print(type(sub))

# %%
sub[1] = 'social'

# %%
fruits.add('grapes')
print(fruits)

# %%
fruits.update(['mango','custard','berry'])
print(fruits)

# %%
fruits.remove('fig')
fruits.discard('watermelon')

# %%
print(fruits)

# %%
fruits.pop()
print(fruits)

# %%
fruits.clear()
print(fruits)

# %%
del fruits

# %%
print(fruits)

# %%
n1 = {12,5,3,8,43,764,12,6}
n2 = {3,65,23,876,32,76,12,43}

uni = n1.union(n2)
print(uni)
len(uni)

# %%
inter = n1.intersection(n2)
print(inter)

# %%
n1diff = n1.difference(n2)
print(n1diff)

# %%
n2diff = n2.difference(n1)
print(n2diff)
