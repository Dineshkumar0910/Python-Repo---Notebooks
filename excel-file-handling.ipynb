# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/test-file/tested.csv

# %%
df = pd.read_csv('/kaggle/input/test-file/tested.csv',encoding="ISO-8859-1")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df['Name']
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
df.groupby('Name')
print(df.groupby('Name').groups)
# Out:
# {'Abbott, Master. Eugene Joseph': [392], 'Abelseth, Miss. Karen Marie': [345], 'Abelseth, Mr. Olaus Jorgensen': [57], 'Abrahamsson, Mr. Abraham August Johannes': [251], 'Abrahim, Mrs. Joseph (Sophie Halaut Easu)': [8], 'Aks, Master. Philip Frank': [307], 'Aldworth, Mr. Charles Augustus': [78], 'Allison, Mr. Hudson Joshua Creighton': [306], 'Andersen, Mr. Albert Karvin': [210], 'Andersson, Miss. Ida Augusta Margareta': [214], 'Andersson, Mr. Johan Samuel': [320], 'Andrew, Mr. Frank Thomas': [204], 'Angheloff, Mr. Minko': [295], 'Angle, Mr. William A': [190], 'Aronsson, Mr. Ernst Axel Algot': [386], 'Ashby, Mr. John': [387], 'Asplund, Master. Carl Edgar': [379], 'Asplund, Master. Filip Oscar': [154], 'Asplund, Mr. Carl Oscar Vilhelm Gustafsson': [174], 'Asplund, Mr. Johan Charles': [226], 'Assaf Khalil, Mrs. Mariana (Miriam")"': [19], 'Assaf, Mr. Gerios': [17], 'Assam, Mr. Ali': [325], 'Astor, Col. John Jacob': [202], 'Baccos, Mr. Raffull': [237], 'Badman, Miss. Emily Louisa': [87], 'Baimbrigge, Mr. Charles Robert': [198], 'Barry, Miss. Julia': [86], 'Beattie, Mr. Thomson': [118], 'Beauchamp, Mr. Henry James': [143], 'Becker, Miss. Ruth Elizabeth': [326], 'Becker, Mrs. Allen Oliver (Nellie E Baumgardner)': [178], 'Bentham, Miss. Lilian W': [258], 'Betros, Master. Seman': [339], 'Bird, Miss. Ellen': [156], 'Birnbaum, Mr. Jakob': [94], 'Bjorklund, Mr. Ernst Herbert': [62], 'Bonnell, Miss. Caroline': [400], 'Borebank, Mr. John James': [158], 'Botsford, Mr. William Hull': [346], 'Boulos, Master. Akar': [80], 'Bowen, Miss. Grace Scott': [375], 'Bowenur, Mr. Solomon': [128], 'Bradley, Miss. Bridget Delia': [63], 'Brady, Mr. John Bertram': [28], 'Braf, Miss. Elin Ester Maria': [98], 'Brandeis, Mr. Emil': [166], 'Brobeck, Mr. Karl Rudolf': [126], 'Brown, Miss. Edith Eileen': [175], 'Brown, Mrs. John Murray (Caroline Lane Lamson)': [356], 'Bryhl, Miss. Dagmar Jenny Ingeborg ': [275], 'Buckley, Miss. Katherine': [113], 'Buckley, Mr. Daniel': [106], 'Bucknell, Mrs. William Robert (Emma Eliza Ward)': [48], 'Burns, Miss. Mary Delia': [66], 'Cacic, Miss. Manda': [37], 'Cacic, Mr. Jego Grga': [310], 'Caldwell, Mr. Albert Francis': [7], 'Canavan, Mr. Patrick': [388], 'Candee, Mrs. Edward (Helen Churchill Hungerford)': [224], 'Caram, Mr. Joseph': [366], 'Cardeza, Mrs. James Warburton Martinez (Charlotte Wardle Drake)': [343], 'Carlsson, Mr. Carl Robert': [135], 'Carr, Miss. Jeannie': [313], 'Carrau, Mr. Jose Pedro': [403], 'Carver, Mr. Alfred John': [123], 'Case, Mr. Howard Brown': [82], 'Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genevieve Fosdick)': [168], 'Cavendish, Mrs. Tyrell William (Julia Florence Siegel)': [96], 'Chaffee, Mrs. Herbert Fuller (Carrie Constance Toogood)': [14], 'Chapman, Mrs. John Henry (Sara Elizabeth Lawry)': [119], 'Chaudanson, Miss. Victorine': [59], 'Chevre, Mr. Paul Romaine': [46], 'Chisholm, Mr. Roderick Robert Crispin': [266], 'Christy, Mrs. (Alice Frances)': [241], 'Chronopoulos, Mr. Demetrios': [115], 'Clark, Mr. Walter Miller': [252], 'Clark, Mrs. Walter Miller (Virginia McDowell)': [272], 'Clarke, Mr. Charles Valentine': [328], 'Colbert, Mr. Patrick': [396], 'Collett, Mr. Sidney C Stuart': [207], 'Compton, Mr. Alexander Taylor Jr': [181], 'Compton, Mrs. Alexander Taylor (Mary Eliza Ingersoll)': [179], 'Conlon, Mr. Thomas Henry': [399], 'Connolly, Miss. Kate': [6], 'Cook, Mrs. (Selena Rogers)': [222], 'Cor, Mr. Bartol': [56], 'Cor, Mr. Ivan': [334], 'Corbett, Mrs. Walter H (Irene Colvin)': [43], 'Corey, Mrs. Percy C (Mary Phyllis Elizabeth Miller)': [65], 'Cornell, Mrs. Robert Clifford (Malvina Helen Lamson)': [77], 'Cotterill, Mr. Henry Harry""': [377], 'Coutts, Mrs. William (Winnie Minnie" Treanor)"': [49], 'Crafton, Mr. John Bertram': [148], 'Cribb, Miss. Laura Alice': [125], 'Crosby, Mrs. Edward Gifford (Catherine Elizabeth Halstead)': [305], 'Cumings, Mr. John Bradley': [234], 'Daher, Mr. Shedid': [27], 'Daly, Miss. Margaret Marcella Maggie""': [291], 'Danbom, Master. Gilbert Sigvard Emanuel': [201], ...}

# %%
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 24           916         1       1
# 26           918         1       1
# 28           920         0       1
# ..           ...       ...     ...
# 404         1296         0       1
# 405         1297         0       2
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                        Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                             Brady, Mr. John Bertram    male  41.0      0
# ..                                                 ...     ...   ...    ...
# 404                       Frauenthal, Mr. Isaac Gerald    male  43.0      1
# 405       Nourney, Mr. Alfred (Baron von Drachstedt")"    male  20.0      0
# 407                         Widener, Mr. George Dunton    male  50.0      1
# 411    Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 414                       Oliva y Ocana, Dona. Fermina  female  39.0      0
#
#      Parch         Ticket      Fare            Cabin Embarked
# 12       0          21228   82.2667              B45        S
# 14       0    W.E.P. 5734   61.1750              E31        S
# 24       3       PC 17608  262.3750  B57 B59 B63 B66        C
# 26       1         113509   61.9792              B36        C
# 28       0         113054   30.5000              A21        S
# ..     ...            ...       ...              ...      ...
# 404      0          17765   27.7208              D40        C
# 405      0  SC/PARIS 2166   13.8625              D38        C
# 407      1         113503  211.5000              C80        C
# 411      0          19928   90.0000              C78        Q
# 414      0       PC 17758  108.9000             C105        C
#
# [87 rows x 12 columns]

# %%
print(df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Length: 418, dtype: bool

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.023245 -0.026751 -0.034102  0.003818  0.043080
# Survived       -0.023245  1.000000 -0.108615 -0.000013  0.099943  0.159120
# Pclass         -0.026751 -0.108615  1.000000 -0.492143  0.001087  0.018721
# Age            -0.034102 -0.000013 -0.492143  1.000000 -0.091587 -0.061249
# SibSp           0.003818  0.099943  0.001087 -0.091587  1.000000  0.306895
# Parch           0.043080  0.159120  0.018721 -0.061249  0.306895  1.000000
# Fare            0.008211  0.191514 -0.577147  0.337932  0.171539  0.230046
#
#                  Fare
# PassengerId  0.008211
# Survived     0.191514
# Pclass      -0.577147
# Age          0.337932
# SibSp        0.171539
# Parch        0.230046
# Fare         1.000000

# %%
import matplotlib.pyplot as plt

# %%
x = df['Age']
y = df['Survived']
plt.bar(x,y)
plt.show()

# %%
e = (0.1,0,0,0)
plt.pie(y)
plt.show()

# %%
import seaborn as sns

# %%
sns.histplot(x='Name',y='Age',data=df)
plt.show()

# %%
sns.pairplot(data=df, hue='Age')
plt.show()
