# %%
my_list1 = [3,5,7,1]
my_list2 = ['chennai','madurai',454,1223]
print(my_list1)
print(my_list2)
# Out:
# [3, 5, 7, 1]
# ['chennai', 'madurai', 454, 1223]

# %%
len(my_list1)
len(my_list2)
# Out:
# 4

# %%
my_list2[0]
# Out:
# 'chennai'

# %%
my_list2[1:]
# Out:
# ['madurai', 454, 1223]

# %%
my_list2[:3]
# Out:
# ['chennai', 'madurai', 454]

# %%
my_list2 = my_list2 + ['delhi']

# %%
my_list2
# Out:
# ['chennai', 'madurai', 454, 1223, 'delhi', 'delhi']

# %%
my_list2.append('bangaluru')
my_list2
# Out:
# ['chennai', 'madurai', 454, 1223, 'delhi', 'delhi', 'bangaluru']

# %%
my_list2.insert(4,50)
my_list2
# Out:
# ['chennai', 'madurai', 454, 1223, 50, 'delhi', 'delhi', 'bangaluru']

# %%
my_list2.extend(my_list1)
my_list2
# Out:
# ['chennai',
#  'madurai',
#  454,
#  1223,
#  50,
#  'delhi',
#  'delhi',
#  'bangaluru',
#  3,
#  5,
#  7,
#  1]

# %%
my_list2.pop()
my_list2
# Out:
# ['chennai', 'madurai', 454, 1223, 50, 'delhi', 'delhi', 'bangaluru', 3, 5, 7]

# %%
my_list2.pop(3)
my_list2
# Out:
# ['chennai', 'madurai', 454, 50, 'delhi', 'delhi', 'bangaluru', 3, 5, 7]

# %%
my_list1.sort()
my_list1
my_list1.reverse()
my_list1
# Out:
# [7, 5, 3, 1]

# %%
#Nested list
nest_list=[my_list1,my_list2]
nest_list
# Out:
# [[7, 5, 3, 1],
#  ['chennai', 'madurai', 454, 50, 'delhi', 'delhi', 'bangaluru', 3, 5, 7]]

# %%
nest_list[0]
# Out:
# [7, 5, 3, 1]

# %%
nest_list[0][1]
# Out:
# 5

# %%
my_list2.clear()
my_list2
# Out:
# []

# %%
del my_list2
my_list2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27/3618420260.py in <module>
#       1 del my_list2
# ----> 2 my_list2
#
# NameError: name 'my_list2' is not defined
